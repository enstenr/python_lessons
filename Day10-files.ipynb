# %%
# get current working directory
import os

os.getcwd()
os.path.basename(os.getcwd())
# Out:
# 'Notebooks'

# %%
for base,dirs,fids in os.walk(os.getcwd()):
    print(fids)
# Out:
# ['class1.py.txt', 'Credentials.url', 'My Daily Diary.url', 'Numpy.ipynb', 'README.md', 'Untitled.ipynb', 'Day9-recursion.ipynb', 'Day8-lambda.ipynb', 'Day7-generators.ipynb', 'Day7-functions.ipynb', 'SentimentAnalysis.ipynb', 'IMG_20241211_135207427_AE.jpg', 'image_analysis.ipynb', 'EdgeDetection.ipynb', 'ClassTest.ipynb']
# ['COMMIT_EDITMSG', 'config', 'description', 'FETCH_HEAD', 'HEAD', 'index']
# ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'update.sample']
# ['exclude']
# ['HEAD']
# []
# ['master']
# []
# ['master']
# []
# ['8f6571243461c0b6f5bb68bb0eb12fa12ef511']
# ['77c6e0e387cb79e41e039c2708c16f79ea934a']
# ['d7b86dec5d134168259655bda858f3df98ded4']
# ['93efcef9a625a39a3d8e0814cf77433665d23d']
# ...

# %%
fid = open('../Documents/countries.txt')
print(fid.readline())
print(fid.readline())
# Out:
# Country
#
# Afghanistan

# %%
# for more number oflines, we can use as below 
with open('../Documents/countries.txt') as fid:
    for line in fid:
        print(line)
# Out:
# Country
#
# Afghanistan
#
# Albania
#
# Algeria
#
# American Samoa
#
# Andorra
#
# Angola
#
# Anguilla
#
# Antigua & Barbuda
#
# Argentina
#
# Armenia
#
# Aruba
#
# Australia
#
# Austria
#
# Azerbaijan
#
# Bahamas, The
#
# Bahrain
#
# Bangladesh
#
# Barbados
#
# Belarus
#
# Belgium
#
# Belize
#
# Benin
#
# Bermuda
#
# Bhutan
#
# Bolivia
#
# Bosnia & Herzegovina
#
# Botswana
#
# Brazil
#
# British Virgin Is.
#
# Brunei
#
# Bulgaria
#
# Burkina Faso
#
# Burma
#
# Burundi
#
# Cambodia
#
# Cameroon
#
# Canada
#
# Cape Verde
#
# Cayman Islands
#
# Central African Rep.
#
# Chad
#
# Chile
#
# China
#
# Colombia
#
# Comoros
#
# Congo, Dem. Rep.
#
# Congo, Repub. of the
#
# Cook Islands
#
# Costa Rica
#
# Cote d'Ivoire
#
# Croatia
#
# Cuba
#
# Cyprus
#
# Czech Republic
#
# Denmark
#
# Djibouti
#
# Dominica
#
# Dominican Republic
#
# East Timor
#
# Ecuador
#
# Egypt
#
# El Salvador
#
# Equatorial Guinea
#
# Eritrea
#
# Estonia
#
# Ethiopia
#
# Faroe Islands
#
# Fiji
#
# Finland
#
# France
#
# ...

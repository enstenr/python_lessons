# %%
import pandas as pd

degrees = pd.read_csv('data/mysql/degrees.csv')
display(degrees)
display(degrees.columns)

lecturers = pd.read_csv('data/mysql/lecturers.csv')
display(lecturers)

modules = pd.read_csv('data/mysql/modules.csv')
display(modules)

students = pd.read_csv('data/mysql/students.csv')
display(students)

degree_modules = pd.read_csv('data/mysql/degree_modules.csv')
display(degree_modules)

lecturer_module = pd.read_csv('data/mysql/lecturer_module.csv')
display(lecturer_module)

student_module_grades = pd.read_csv('data/mysql/student_module_grades.csv')
display(student_module_grades)
# Out:
#      Code                       Name Type  Years  Credits
# 0  MS56DS  Data Science for Business  MSc      1      180
# 1  MS44BD                   Big Data  MSc      1      180
# Index(['Code', 'Name', 'Type', 'Years', 'Credits'], dtype='object')
#     StaffID                  Name             Position
# 0    100342        Kevin Swingler      Senior Lecturer
# 1    100548        Sandy Brownlee             Lecturer
# 2    100769         Paul McMenemy             Lecturer
# 3    100571           Najib Murad             Lecturer
# 4    100327              Tom Kane      Senior Lecturer
# 5    100776        Gabriela Ochoa            Professor
# 6    100672           John Bowers            Professor
# 7    100923          David Cairns             Lecturer
# 8    100663         Jozsef Farkas               Reader
# 9    100751          Simona Hapca             Lecturer
# 10   100328           Gerry Edgar      Senior Lecturer
# 11   100554        Carol Marshall             Lecturer
# ...

# %%
display(degrees.columns)
display(lecturers.columns)
print(modules.columns, students.columns, degree_modules.columns, lecturer_module.columns, student_module_grades.columns)
# Out:
# Index(['Code', 'Name', 'Type', 'Years', 'Credits'], dtype='object')
# Index(['StaffID', 'Name', 'Position'], dtype='object')
# Index(['Module', 'Name', 'Credits', 'Semester'], dtype='object') Index(['Number', 'Surname', 'Gender', 'userID', 'Degree', 'Complete'], dtype='object') Index(['Degree', 'Module'], dtype='object') Index(['StaffID', 'Module'], dtype='object') Index(['208456', 'ITNPBD2', '67'], dtype='object')
